# %%
import requests
from bs4 import BeautifulSoup
from textblob import TextBlob

# %%
# URL of the Twitter account or search results page to scrape
url = "https://twitter.com/JoeBiden/status/1688635121484627968"

# %%
url
# Out:
# 'https://twitter.com/JoeBiden/status/1688635121484627968'

# %%
# Send a GET request and parse the HTML with BeautifulSoup
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# ...

# %%
tweets = soup.find_all("p", class_="tweet-text")  # Extract tweet text
positive_count = 0
negative_count = 0
neutral_count = 0

# %%
tweets
# Out:
# []

# %%
# Analyze sentiment using TextBlob
for tweet in tweets:
    cleaned_tweet = preprocess(tweet.get_text())  # Implement preprocess function
    analysis = TextBlob(cleaned_tweet)
    
    if analysis.sentiment.polarity > 0:
        positive_count += 1
    elif analysis.sentiment.polarity < 0:
        negative_count += 1
    else:
        neutral_count += 1

# Print sentiment analysis results
print("Positive:", positive_count)
print("Negative:", negative_count)
print("Neutral:", neutral_count)
# Out:
# Positive: 0
# Negative: 0
# Neutral: 0
